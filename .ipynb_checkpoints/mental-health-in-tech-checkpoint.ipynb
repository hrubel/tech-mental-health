# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
data = pd.read_csv ('survey.csv')

# %%
pd.set_option('display.max_columns', None)
data.head()
# Out:
#              Timestamp  Age  Gender         Country state self_employed  \
# 0  2014-08-27 11:29:31   37  Female   United States    IL           NaN
# 1  2014-08-27 11:29:37   44       M   United States    IN           NaN
# 2  2014-08-27 11:29:44   32    Male          Canada   NaN           NaN
# 3  2014-08-27 11:29:46   31    Male  United Kingdom   NaN           NaN
# 4  2014-08-27 11:30:22   31    Male   United States    TX           NaN
#
#   family_history treatment work_interfere    no_employees remote_work  \
# 0             No       Yes          Often            6-25          No
# 1             No        No         Rarely  More than 1000          No
# 2             No        No         Rarely            6-25          No
# 3            Yes       Yes          Often          26-100          No
# 4             No        No          Never         100-500         Yes
#
#   tech_company    benefits care_options wellness_program   seek_help  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 27 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Timestamp                  1259 non-null   object
#  1   Age                        1259 non-null   int64
#  2   Gender                     1259 non-null   object
#  3   Country                    1259 non-null   object
#  4   state                      744 non-null    object
#  5   self_employed              1241 non-null   object
#  6   family_history             1259 non-null   object
#  7   treatment                  1259 non-null   object
#  8   work_interfere             995 non-null    object
#  9   no_employees               1259 non-null   object
#  10  remote_work                1259 non-null   object
#  11  tech_company               1259 non-null   object
#  12  benefits                   1259 non-null   object
# ...

# %%
data.dtypes
# Out:
# Timestamp                    object
# Age                           int64
# Gender                       object
# Country                      object
# state                        object
# self_employed                object
# family_history               object
# treatment                    object
# work_interfere               object
# no_employees                 object
# remote_work                  object
# tech_company                 object
# benefits                     object
# care_options                 object
# wellness_program             object
# seek_help                    object
# anonymity                    object
# leave                        object
# mental_health_consequence    object
# phys_health_consequence      object
# coworkers                    object
# supervisor                   object
# mental_health_interview      object
# phys_health_interview        object
# mental_vs_physical           object
# obs_consequence              object
# ...

# %%
data.Gender.value_counts()
# Out:
# Male          989
# Female        247
# Non-binary     17
# Name: Gender, dtype: int64

# %%
data['Gender'] = data["Gender"].replace(["male","M","m","Make","Man","Male ","Cis Male",
                                         "Male-ish","Cis Man","maile","Male (CIS)",
                                         "ostensibly male, unsure what that really means",
                                         "cis male","Guy (-ish) ^_^","Mal","msle","Mail","Malr"],"Male")

# %%
data['Gender'] = data["Gender"].replace(["female","f","F","Female ","Woman","Cis Female",
                                         "femail","Femake","woman ","Female (cis)",
                                         "cis-female/femme","woman"],"Female")

# %%
data['Gender'] = data["Gender"].replace(["Female (trans)","Enby","Nah","All","Agender",
                                         "Trans woman","Trans-female","non-binary","Neuter",
                                        "Androgyne","p","A little about you","queer",
                                        "queer/she/they","Genderqueer","fluid","male leaning androgynous"
                                         ,"something kinda male?"],"Non-binary")

# %%
data.Age.value_counts()
# Out:
# 29    85
# 32    82
# 26    75
# 27    71
# 33    70
# 28    68
# 31    67
# 34    65
# 30    63
# 25    61
# 35    55
# 23    51
# 24    46
# 37    43
# 38    39
# 36    37
# 40    33
# 39    33
# 43    28
# 22    21
# 41    21
# 42    20
# 21    16
# 45    12
# 46    12
# 44    11
# 19     9
# 18     7
# 48     6
# 50     6
# 20     6
# 51     5
# 49     4
# 56     4
# 54     3
# 55     3
# 57     3
# 47     2
# 60     2
# 11     1
# 72     1
# 65     1
# 53     1
# 58     1
# 61     1
# 62     1
# 8      1
# Name: Age, dtype: int64

# %%
print(data.loc[data['Age']== 99999999999])
# Out:
#                Timestamp          Age      Gender   Country state  \
# 390  2014-08-27 15:24:47  99999999999  Non-binary  Zimbabwe   NaN
#
#     self_employed family_history treatment work_interfere no_employees  \
# 390           Yes            Yes       Yes          Often          1-5
#
#     remote_work tech_company benefits care_options wellness_program seek_help  \
# 390          No          Yes       No          Yes               No        No
#
#     anonymity           leave mental_health_consequence  \
# 390        No  Very difficult                       Yes
#
#     phys_health_consequence coworkers supervisor mental_health_interview  \
# 390                     Yes        No         No                     Yes
#
#     phys_health_interview mental_vs_physical obs_consequence comments
# 390                    No                 No             Yes      NaN

# %%
data=data.drop([data.index[734],data.index[390],data.index[715],data.index[364],data.index[143],data.index[1127]])

# %%
data.treatment.value_counts()
# Out:
# Yes    633
# No     620
# Name: treatment, dtype: int64

# %%
data.head()
# Out:
#              Timestamp  Age  Gender         Country state self_employed  \
# 0  2014-08-27 11:29:31   37  Female   United States    IL           NaN
# 1  2014-08-27 11:29:37   44    Male   United States    IN           NaN
# 2  2014-08-27 11:29:44   32    Male          Canada   NaN           NaN
# 3  2014-08-27 11:29:46   31    Male  United Kingdom   NaN           NaN
# 4  2014-08-27 11:30:22   31    Male   United States    TX           NaN
#
#   family_history treatment work_interfere    no_employees remote_work  \
# 0             No       Yes          Often            6-25          No
# 1             No        No         Rarely  More than 1000          No
# 2             No        No         Rarely            6-25          No
# 3            Yes       Yes          Often          26-100          No
# 4             No        No          Never         100-500         Yes
#
#   tech_company    benefits care_options wellness_program   seek_help  \
# ...
